# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhs777c/python-practice/blob/main/basic_hb_anal_practice_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df= pd.read_csv('/content/drive/MyDrive/HOTEL BOOKING EDA/Copy of Hotel Bookings.csv')
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head(3)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# ...

# %%
df.tail(2)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119388                         31                        2
# 119389                         29                        2
#
#         stays_in_week_nights  adults  ...  deposit_type  agent company  \
# 119388                     5       2  ...    No Deposit   89.0     NaN
# 119389                     7       2  ...    No Deposit    9.0     NaN
#
#        days_in_waiting_list customer_type    adr  required_car_parking_spaces  \
# 119388                    0     Transient  104.4                            0
# ...

# %%
df.iloc[0]
# Out:
# hotel                             Resort Hotel
# is_canceled                                  0
# lead_time                                  342
# arrival_date_year                         2015
# arrival_date_month                        July
# arrival_date_week_number                    27
# arrival_date_day_of_month                    1
# stays_in_weekend_nights                      0
# stays_in_week_nights                         0
# adults                                       2
# children                                   0.0
# babies                                       0
# meal                                        BB
# country                                    PRT
# market_segment                          Direct
# distribution_channel                    Direct
# is_repeated_guest                            0
# previous_cancellations                       0
# previous_bookings_not_canceled               0
# reserved_room_type                           C
# ...

# %%
df.iloc[0:5]
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.iloc[[1,3,5,7]]
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 1  Resort Hotel            0        737               2015               July
# 3  Resort Hotel            0         13               2015               July
# 5  Resort Hotel            0         14               2015               July
# 7  Resort Hotel            0          9               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 1                        27                          1
# 3                        27                          1
# 5                        27                          1
# 7                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 1                        0                     0       2  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# ...

# %%
df.iloc[:,[0,1,2,3]]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
# [119390 rows x 4 columns]

# %%
mask=df['arrival_date_year']==2015
df[mask].shape[0]
# Out:
# 21996

# %%
def arrival_year(arrival_date_year):
    mask=df['arrival_date_year']==arrival_date_year
    return df[mask].shape[0]

# %%
arrival_year(2016)
# Out:
# 56707

# %%
arrival_year(2017)
# Out:
# 40687

# %%
mask1=df['hotel']=='City Hotel'
mask2=df['arrival_date_year']==2015
df[mask1 & mask2].shape[0]
# Out:
# 13682

# %%
mask1=df['hotel']=='City Hotel'
mask2=df['arrival_date_year']==2016
df[mask1 & mask2].shape[0]
# Out:
# 38140

# %%
mask1=df['hotel']=='City Hotel'
mask2=df['arrival_date_year']==2017
df[mask1 & mask2].shape[0]
# Out:
# 27508

# %%
mask1=df['hotel']=='Resort Hotel'
mask2=df['arrival_date_year']==2015
df[mask1 & mask2].shape[0]
# Out:
# 8314

# %%
mask1=df['hotel']=='Resort Hotel'
mask2=df['arrival_date_year']==2016
df[mask1 & mask2].shape[0]
# Out:
# 18567

# %%
mask1=df['hotel']=='Resort Hotel'
mask2=df['arrival_date_year']==2017
df[mask1 & mask2].shape[0]
# Out:
# 13179

# %%
df['hotel'].value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
df['arrival_date_month'].value_counts()
# Out:
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: arrival_date_month, dtype: int64

# %%
df['deposit_type'].value_counts()
# Out:
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: deposit_type, dtype: int64

# %%
df['customer_type'].value_counts()
# Out:
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: customer_type, dtype: int64

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: market_segment, dtype: int64

# %%
df['distribution_channel'].value_counts().sort_values(ascending=False)
# Out:
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: distribution_channel, dtype: int64

# %%
df['market_segment'].value_counts() + df['distribution_channel'].value_counts()
# Out:
# Aviation             NaN
# Complementary        NaN
# Corporate        11972.0
# Direct           27251.0
# GDS                  NaN
# Groups               NaN
# Offline TA/TO        NaN
# Online TA            NaN
# TA/TO                NaN
# Undefined            7.0
# dtype: float64

# %%
df['arrival_date_month'].value_counts().head(6).plot(kind='barh')
# Out:
# <Axes: >

# %%
df['customer_type'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='customer_type'>

# %%
df['lead_time'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.head(2)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type  adr  \
# 0    NaN     NaN                    0     Transient  0.0
# 1    NaN     NaN                    0     Transient  0.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# ...

# %%
df.sort_values('arrival_date_month',ascending=True)
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 87641    City Hotel            0         60               2016
# 87091    City Hotel            0         26               2016
# 87090    City Hotel            0          7               2016
# 87089    City Hotel            0         21               2016
# 87088    City Hotel            0         64               2016
# ...             ...          ...        ...                ...
# 8398   Resort Hotel            1        347               2016
# 8397   Resort Hotel            0        542               2016
# 8396   Resort Hotel            1         19               2016
# 8404   Resort Hotel            1        339               2016
# 98043    City Hotel            0        116               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 87641              April                        17                         18
# ...

# %%
df.sort_values(['arrival_date_year' ,'arrival_date_year'],ascending=[True,False]).head(2)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type  adr  \
# 0    NaN     NaN                    0     Transient  0.0
# 1    NaN     NaN                    0     Transient  0.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# ...

# %%
df.drop_duplicates().shape[0]
# Out:
# 87396

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.drop_duplicates('hotel',keep='first')[['hotel','arrival_date_month','arrival_date_year']].sort_values('hotel')
# Out:
#               hotel arrival_date_month  arrival_date_year
# 40060    City Hotel               July               2015
# 0      Resort Hotel               July               2015

# %%
df.drop_duplicates('hotel',keep='last')[['hotel','arrival_date_month','arrival_date_year']].sort_values('hotel')
# Out:
#                hotel arrival_date_month  arrival_date_year
# 119389    City Hotel             August               2017
# 40059   Resort Hotel             August               2017

# %%
name=df.groupby('hotel').count()
name
# Out:
#               is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# hotel
# City Hotel          79330      79330              79330               79330
# Resort Hotel        40060      40060              40060               40060
#
#               arrival_date_week_number  arrival_date_day_of_month  \
# hotel
# City Hotel                       79330                      79330
# Resort Hotel                     40060                      40060
#
#               stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# hotel
# City Hotel                      79330                 79330   79330     79326
# Resort Hotel                    40060                 40060   40060     40060
#
#               ...  deposit_type  agent  company  days_in_waiting_list  \
# hotel         ...
# City Hotel    ...         79330  71199     3689                 79330
# Resort Hotel  ...         40060  31851     3108                 40060
#
# ...

# %%
month_count=df.groupby('arrival_date_month').count()
month_count
# Out:
#                     hotel  is_canceled  lead_time  arrival_date_year  \
# arrival_date_month
# April               11089        11089      11089              11089
# August              13877        13877      13877              13877
# December             6780         6780       6780               6780
# February             8068         8068       8068               8068
# January              5929         5929       5929               5929
# July                12661        12661      12661              12661
# June                10939        10939      10939              10939
# March                9794         9794       9794               9794
# May                 11791        11791      11791              11791
# November             6794         6794       6794               6794
# October             11160        11160      11160              11160
# September           10508        10508      10508              10508
#
# ...

# %%
hotel_count = month_count['hotel']
hotel_count
# Out:
# arrival_date_month
# April        11089
# August       13877
# December      6780
# February      8068
# January       5929
# July         12661
# June         10939
# March         9794
# May          11791
# November      6794
# October      11160
# September    10508
# Name: hotel, dtype: int64

# %%
hotel_month_count = df.groupby(['arrival_date_month', 'hotel']).count().sort_values('arrival_date_month')
hotel_month_count.iloc[:,2]
# Out:
# arrival_date_month  hotel
# April               City Hotel      7480
#                     Resort Hotel    3609
# August              City Hotel      8983
#                     Resort Hotel    4894
# December            City Hotel      4132
#                     Resort Hotel    2648
# February            City Hotel      4965
#                     Resort Hotel    3103
# January             City Hotel      3736
#                     Resort Hotel    2193
# July                Resort Hotel    4573
#                     City Hotel      8088
# June                City Hotel      7894
#                     Resort Hotel    3045
# March               City Hotel      6458
#                     Resort Hotel    3336
# May                 City Hotel      8232
#                     Resort Hotel    3559
# November            City Hotel      4357
#                     Resort Hotel    2437
# October             City Hotel      7605
#                     Resort Hotel    3555
# ...

# %%
list(df.columns)
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date']
